# %%
#selecting data for modeling
import pandas as pd
malbourne_data=pd.read_csv('C:/Users/Akib/Desktop/mhp/mphp.csv')
malbourne_data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Postcode', 'Regionname', 'Propertycount', 'Distance',
#        'CouncilArea'],
#       dtype='object')

# %%
# The Melbourne data has some missing values (some houses for which some variables weren't recorded.)
# We'll learn to handle missing values in a later tutorial.  
# Your Iowa data doesn't have missing values in the columns you use. 
# So we will take the simplest option for now, and drop houses from our data. 
# Don't worry about this much for now, though the code is:

# dropna drops missing values (think of na as "not available")
malbourne_data = malbourne_data.dropna(axis=0)

# %% [markdown]
# # Selecting The Prediction Target

# %%
y=malbourne_data.Price

# %%
y
# Out:
# 0        1490000.0
# 1        1220000.0
# 2        1420000.0
# 3        1515000.0
# 4         670000.0
# 5         530000.0
# 6         540000.0
# 7         715000.0
# 9        1925000.0
# 10        515000.0
# 11        717000.0
# 12       1675000.0
# 13       2008000.0
# 14        860000.0
# 16        720000.0
# 17        836000.0
# 18       2110000.0
# 19       1386000.0
# 20        580000.0
# 21        355000.0
# 22       1123100.0
# 23       1270000.0
# 25       1610000.0
# 26       1435000.0
# 27       1431000.0
# 28        996000.0
# 30        825000.0
# 31        660800.0
# 32        700000.0
# 33       2700000.0
#            ...
# 62985    1700000.0
# 62986    1100000.0
# 62987     785000.0
# 62988    1115000.0
# 62989     570000.0
# 62990     870000.0
# 62991    2400000.0
# 62993    1000000.0
# 62994     640000.0
# 62995     520600.0
# 62997     410000.0
# 62998     400000.0
# 63000     416000.0
# 63002     745000.0
# 63003     655000.0
# 63004     870000.0
# ...

# %% [markdown]
# # Choosing "Features"

# %%
malbourne_features=['Rooms', 'Type', 'Price', 'Method', 'SellerG']

# %%
X=malbourne_data[malbourne_features]

# %%
X
# Out:
#        Rooms Type      Price Method        SellerG
# 0          3    h  1490000.0      S         Jellis
# 1          3    h  1220000.0      S       Marshall
# 2          3    h  1420000.0      S         Nelson
# 3          3    h  1515000.0      S          Barry
# 4          2    h   670000.0      S         Nelson
# 5          2    t   530000.0      S         Jellis
# 6          2    u   540000.0      S          Barry
# 7          3    h   715000.0     SP         Nelson
# 9          3    h  1925000.0      S         Cayzer
# 10         3    u   515000.0      S        Douglas
# 11         4    h   717000.0      S          Bells
# 12         2    h  1675000.0      S          Miles
# 13         4    h  2008000.0      S         Jellis
# 14         2    h   860000.0     SP         Barlow
# 16         3    h   720000.0      S         Hunter
# 17         2    u   836000.0      S         Jellis
# 18         2    h  2110000.0      S         Jellis
# ...

# %%
X.describe()
# Out:
#               Rooms         Price
# count  48433.000000  4.843300e+04
# mean       3.071666  9.978982e+05
# std        0.944708  5.934989e+05
# min        1.000000  8.500000e+04
# 25%        2.000000  6.200000e+05
# 50%        3.000000  8.300000e+05
# 75%        4.000000  1.220000e+06
# max       31.000000  1.120000e+07

# %%
X.head(10)
# Out:
#     Rooms Type      Price Method   SellerG
# 0       3    h  1490000.0      S    Jellis
# 1       3    h  1220000.0      S  Marshall
# 2       3    h  1420000.0      S    Nelson
# 3       3    h  1515000.0      S     Barry
# 4       2    h   670000.0      S    Nelson
# 5       2    t   530000.0      S    Jellis
# 6       2    u   540000.0      S     Barry
# 7       3    h   715000.0     SP    Nelson
# 9       3    h  1925000.0      S    Cayzer
# 10      3    u   515000.0      S   Douglas

# %% [markdown]
# # Building  Model

# %%
from sklearn.tree import DecisionTreeRegressor

# Define model. Specify a number for random_state to ensure same results each run
malbourne_model = DecisionTreeRegressor(random_state=1)

# Fit model
malbourne_model.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-3da08f74e6ea> in <module>
#       5
#       6 # Fit model
# ----> 7 malbourne_model.fit(X,y)
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1140             sample_weight=sample_weight,
#    1141             check_input=check_input,
# -> 1142             X_idx_sorted=X_idx_sorted)
#    1143         return self
#    1144
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# --> 116             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     117             y = check_array(y, ensure_2d=False, dtype=None)
#     118             if issparse(X):
#
# ...

# %%
print("Making predictions for the following 5 houses:")
print(X.head())
print("The predictions are")
print(malbourne_model.predict(X.head()))
# Out:
# Making predictions for the following 5 houses:
#    Rooms Type      Price Method   SellerG
# 0      3    h  1490000.0      S    Jellis
# 1      3    h  1220000.0      S  Marshall
# 2      3    h  1420000.0      S    Nelson
# 3      3    h  1515000.0      S     Barry
# 4      2    h   670000.0      S    Nelson
# The predictions are
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-15-02469563dc59> in <module>
#       2 print(X.head())
#       3 print("The predictions are")
# ----> 4 print(malbourne_data.predict(X.head()))
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in predict(self, X, check_input)
#     413             The predicted classes, or the predict values.
#     414         """
# --> 415         check_is_fitted(self, 'tree_')
#     416         X = self._validate_X_predict(X, check_input)
#     417         proba = self.tree_.predict(X)
#
# ...
