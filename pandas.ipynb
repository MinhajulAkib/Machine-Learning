# %% [markdown]
# # 10 minutes pandas

# %% [markdown]
# # import pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Object creation

# %%
#Creating a Series by passing a list of values, letting pandas create a default integer index:
s=pd.Series([1,2,3,np.nan,6,8])

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
#Creating a DataFrame by passing a NumPy array, with a datetime index and labeled columns:
dates=pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df=pd.DataFrame(np.random.randn(6,4), index=dates , columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -1.827746 -0.334015  0.972055  1.831889
# 2013-01-02  1.058816  0.775318 -0.580584 -1.088645
# 2013-01-03 -0.547175  0.085942  0.988334 -0.341121
# 2013-01-04  1.636854 -1.473423 -1.443586  0.955099
# 2013-01-05 -0.277173  0.171142 -0.755639 -0.550787
# 2013-01-06 -0.144820  0.220857  1.151011 -0.454426

# %%
df2 = pd.DataFrame({'A': 1.,
                   'B': pd.Timestamp('20130102'),
                   'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                   'D': np.array([3] * 4, dtype='int32'),
                   'E': pd.Categorical(["test", "train", "test", "train"]),
                   'F': 'foo'})

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
#dataframe have different types
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# # DATA STRUCTURE

# %%
import numpy as np
import pandas as pd

# %%
#create a series from ndarray
s=pd.Series(np.random.randn(5),index=['a','b','c','d','e'])
s
# Out:
# a    0.420013
# b   -1.040139
# c   -0.520172
# d   -0.318507
# e    1.454361
# dtype: float64

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
pd.Series(np.random.randn(5))
# Out:
# 0   -0.580505
# 1   -0.089419
# 2   -1.202068
# 3   -0.009483
# 4    1.107911
# dtype: float64

# %% [markdown]
# # FROM DICTIONARY

# %%
D={'b':1,'a' : 0,'c' :2}
pd.Series(D)
# Out:
# b    1
# a    0
# c    2
# dtype: int64

# %%
pd.Series(D, index=['b', 'c', 'd', 'a'])
# Out:
# b    1.0
# c    2.0
# d    NaN
# a    0.0
# dtype: float64

# %% [markdown]
# # From scalar value

# %%
pd.Series(5., index=['a', 'b', 'c', 'd', 'e'])
# Out:
# a    5.0
# b    5.0
# c    5.0
# d    5.0
# e    5.0
# dtype: float64

# %% [markdown]
# # Series is ndarray-like

# %%
s
# Out:
# a    0.420013
# b   -1.040139
# c   -0.520172
# d   -0.318507
# e    1.454361
# dtype: float64

# %%
s[0]
# Out:
# 0.42001322658656487

# %%
s[:3]
# Out:
# a    0.420013
# b   -1.040139
# c   -0.520172
# dtype: float64

# %%
s[3:]
# Out:
# d   -0.318507
# e    1.454361
# dtype: float64

# %%
s[s>s.median()]
# Out:
# a    0.420013
# e    1.454361
# dtype: float64

# %%
s[[4,3,1]]
# Out:
# e    1.454361
# d   -0.318507
# b   -1.040139
# dtype: float64

# %%
np.exp(s)
# Out:
# a    1.521982
# b    0.353405
# c    0.594418
# d    0.727234
# e    4.281746
# dtype: float64

# %%
s.dtype
# Out:
# dtype('float64')

# %%
s.array
# Out:
# <PandasArray>
# [0.42001322658656487, -1.0401394381289333, -0.5201722947897583,
#  -0.3185073845708598,  1.4543608370949646]
# Length: 5, dtype: float64

# %%
s.to_numpy()
# Out:
# array([ 0.42001323, -1.04013944, -0.52017229, -0.31850738,  1.45436084])

# %% [markdown]
# # series in DICT

# %%
s['a']
# Out:
# 0.42001322658656487

# %%
'e' in s
# Out:
# True

# %%
#Using the get method, a missing label will return None or specified default:
s.get('f')

# %%
s.get('f',np.nan)
# Out:
# nan

# %% [markdown]
# # Name attribute

# %%
s=pd.Series(np.random.randn(5),name='something')

# %%
s
# Out:
# 0    0.265623
# 1   -2.224783
# 2    0.426815
# 3    0.026556
# 4    0.577207
# Name: something, dtype: float64

# %%
s.name
# Out:
# 'something'

# %% [markdown]
# # %%%%DataFrame%%%%

# %%
#From dict of Series or dicts
d = {'one': pd.Series([1., 2., 3.], index=['a', 'b', 'c']),
        'two': pd.Series([1., 2., 3., 4.], index=['a', 'b', 'c', 'd'])}

# %%
df=pd.DataFrame(d)

# %%
df
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  NaN  4.0

# %%
#From dict of ndarrays / lists
d = {'one': [1., 2., 3., 4.],
    'two': [4., 3., 2., 1.]}

# %%
pd.DataFrame(d)
# Out:
#    one  two
# 0  1.0  4.0
# 1  2.0  3.0
# 2  3.0  2.0
# 3  4.0  1.0

# %%
pd.DataFrame(d, index=['a', 'b', 'c', 'd'])
# Out:
#    one  two
# a  1.0  4.0
# b  2.0  3.0
# c  3.0  2.0
# d  4.0  1.0

# %%
#selection, addition, deletion
df['one']
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# Name: one, dtype: float64

# %%
df['three'] = df['one'] * df['two']

# %%
df['flag'] = df['one'] > 2

# %%
df
# Out:
#    one  two  three   flag
# a  1.0  1.0    1.0  False
# b  2.0  2.0    4.0  False
# c  3.0  3.0    9.0   True
# d  NaN  4.0    NaN  False

# %%
#delete
del df['two']

# %%
three=df.pop('three')

# %%
df
# Out:
#    one   flag
# a  1.0  False
# b  2.0  False
# c  3.0   True
# d  NaN  False

# %%
#inserting
df['hello']='world'

# %%
df
# Out:
#    one   flag  hello
# a  1.0  False  world
# b  2.0  False  world
# c  3.0   True  world
# d  NaN  False  world

# %%
#Transposing
df[:5].T
# Out:
#            a      b      c      d
# one        1      2      3    NaN
# flag   False  False   True  False
# hello  world  world  world  world

# %%
# reads csv file into 
bike = pd.read_csv('C:/Users/Akib/Desktop/ML in R/bikeshare.csv')

# %%
bike.head()
# Out:
#      MONTH HOLIDAY WEEKDAY  WEATHERSIT      TEMP     ATEMP  HUMIDITY  \
# 0  JANUARY      NO      NO           2  0.344167  0.363625  0.805833
# 1  JANUARY      NO      NO           2  0.363478  0.353739  0.696087
# 2  JANUARY      NO     YES           1  0.196364  0.189405  0.437273
# 3  JANUARY      NO     YES           1  0.200000  0.212122  0.590435
# 4  JANUARY      NO     YES           1  0.226957  0.229270  0.436957
#
#    WINDSPEED  CASUAL  REGISTERED  COUNT
# 0   0.160446     331         654    985
# 1   0.248539     131         670    801
# 2   0.248309     120        1229   1349
# 3   0.160296     108        1454   1562
# 4   0.186900      82        1518   1600

# %%
bike['MONTH'].head()
# Out:
# 0    JANUARY
# 1    JANUARY
# 2    JANUARY
# 3    JANUARY
# 4    JANUARY
# Name: MONTH, dtype: object

# %%
len(bike)
# Out:
# 731

# %% [markdown]
# # Explorer Dataset

# %%
#general information about column
bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 11 columns):
# MONTH         731 non-null object
# HOLIDAY       731 non-null object
# WEEKDAY       731 non-null object
# WEATHERSIT    731 non-null int64
# TEMP          731 non-null float64
# ATEMP         731 non-null float64
# HUMIDITY      731 non-null float64
# WINDSPEED     731 non-null float64
# CASUAL        731 non-null int64
# REGISTERED    731 non-null int64
# COUNT         731 non-null int64
# dtypes: float64(4), int64(4), object(3)
# memory usage: 62.9+ KB

# %%
#summary statistics of numeric columns
bike.describe()
# Out:
#        WEATHERSIT        TEMP       ATEMP    HUMIDITY   WINDSPEED  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     1.395349    0.495385    0.474354    0.627894    0.190486
# std      0.544894    0.183051    0.162961    0.142429    0.077498
# min      1.000000    0.059130    0.079070    0.000000    0.022392
# 25%      1.000000    0.337083    0.337842    0.520000    0.134950
# 50%      1.000000    0.498333    0.486733    0.626667    0.180975
# 75%      2.000000    0.655417    0.608602    0.730209    0.233214
# max      3.000000    0.861667    0.840896    0.972500    0.507463
#
#             CASUAL   REGISTERED        COUNT
# count   731.000000   731.000000   731.000000
# mean    848.176471  3656.172367  4504.348837
# std     686.622488  1560.256377  1937.211452
# min       2.000000    20.000000    22.000000
# 25%     315.500000  2497.000000  3152.000000
# 50%     713.000000  3662.000000  4548.000000
# 75%    1096.000000  4776.500000  5956.000000
# ...

# %%
#how many null value in there
bike.isnull().sum()
# Out:
# MONTH         0
# HOLIDAY       0
# WEEKDAY       0
# WEATHERSIT    0
# TEMP          0
# ATEMP         0
# HUMIDITY      0
# WINDSPEED     0
# CASUAL        0
# REGISTERED    0
# COUNT         0
# dtype: int64

# %%
# How many HOLIDAY and common bikeshare are there?
bike['HOLIDAY'].sum()
# Out:
# '...'

# %%
#boolean filtering
bike[bike['MONTH'] == 'JANUARY']
# Out:
#        MONTH HOLIDAY WEEKDAY  WEATHERSIT      TEMP     ATEMP  HUMIDITY  \
# 0    JANUARY      NO      NO           2  0.344167  0.363625  0.805833
# 1    JANUARY      NO      NO           2  0.363478  0.353739  0.696087
# 2    JANUARY      NO     YES           1  0.196364  0.189405  0.437273
# 3    JANUARY      NO     YES           1  0.200000  0.212122  0.590435
# 4    JANUARY      NO     YES           1  0.226957  0.229270  0.436957
# 5    JANUARY      NO     YES           1  0.204348  0.233209  0.518261
# 6    JANUARY      NO     YES           2  0.196522  0.208839  0.498696
# 7    JANUARY      NO      NO           2  0.165000  0.162254  0.535833
# 8    JANUARY      NO      NO           1  0.138333  0.116175  0.434167
# 9    JANUARY      NO     YES           1  0.150833  0.150888  0.482917
# 10   JANUARY      NO     YES           2  0.169091  0.191464  0.686364
# 11   JANUARY      NO     YES           1  0.172727  0.160473  0.599545
# ...

# %%
 #subsetting with .loc and .iloc
bike[bike.loc[:,'MONTH'].isin(['JANUARY','FEBRUARY','MARCH','DECEMBER'])]
# Out:
#         MONTH HOLIDAY WEEKDAY  WEATHERSIT      TEMP     ATEMP  HUMIDITY  \
# 0     JANUARY      NO      NO           2  0.344167  0.363625  0.805833
# 1     JANUARY      NO      NO           2  0.363478  0.353739  0.696087
# 2     JANUARY      NO     YES           1  0.196364  0.189405  0.437273
# 3     JANUARY      NO     YES           1  0.200000  0.212122  0.590435
# 4     JANUARY      NO     YES           1  0.226957  0.229270  0.436957
# 5     JANUARY      NO     YES           1  0.204348  0.233209  0.518261
# 6     JANUARY      NO     YES           2  0.196522  0.208839  0.498696
# 7     JANUARY      NO      NO           2  0.165000  0.162254  0.535833
# 8     JANUARY      NO      NO           1  0.138333  0.116175  0.434167
# 9     JANUARY      NO     YES           1  0.150833  0.150888  0.482917
# 10    JANUARY      NO     YES           2  0.169091  0.191464  0.686364
# 11    JANUARY      NO     YES           1  0.172727  0.160473  0.599545
# ...

# %%
image_bike=bike[bike.loc[:,'MONTH'].isin(['JANUARY','FEBRUARY','MARCH','DECEMBER'])]
image_bike
# Out:
#         MONTH HOLIDAY WEEKDAY  WEATHERSIT      TEMP     ATEMP  HUMIDITY  \
# 0     JANUARY      NO      NO           2  0.344167  0.363625  0.805833
# 1     JANUARY      NO      NO           2  0.363478  0.353739  0.696087
# 2     JANUARY      NO     YES           1  0.196364  0.189405  0.437273
# 3     JANUARY      NO     YES           1  0.200000  0.212122  0.590435
# 4     JANUARY      NO     YES           1  0.226957  0.229270  0.436957
# 5     JANUARY      NO     YES           1  0.204348  0.233209  0.518261
# 6     JANUARY      NO     YES           2  0.196522  0.208839  0.498696
# 7     JANUARY      NO      NO           2  0.165000  0.162254  0.535833
# 8     JANUARY      NO      NO           1  0.138333  0.116175  0.434167
# 9     JANUARY      NO     YES           1  0.150833  0.150888  0.482917
# 10    JANUARY      NO     YES           2  0.169091  0.191464  0.686364
# 11    JANUARY      NO     YES           1  0.172727  0.160473  0.599545
# ...

# %%
image_bike.plot??

# %%
#this draws it in a cell
# barplot that compares attack of chosen pokemon
image_bike.plot.bar(x='MONTH', y='TEMP', color=['green', 'red', 'blue', 'yellow'], title='Monthly Temparature')

# %% [markdown]
# # CLEAN DATA

# %%
#Renaming columns
bike = bike.rename(columns={'MONTH':'MONTHS'})
poke.columns
# Out:
# Index(['MONTH', 'HOLIDAY', 'WEEKDAY', 'WEATHERSIT', 'TEMP', 'ATEMP',
#        'HUMIDITY', 'WINDSPEED', 'CASUAL', 'REGISTERED', 'COUNT'],
#       dtype='object')

# %%
# Reindex the dataframe, so the first index is 0 and the last is n-1
nodup_bike.reset_index(inplace=True, drop=True)
nodup_bike.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-117-cb5d291665c3> in <module>
#       1 # Reindex the dataframe, so the first index is 0 and the last is n-1
# ----> 2 nodup_bike.reset_index(inplace=True, drop=True)
#       3 nodup_bike.head()
#
# NameError: name 'nodup_bike' is not defined
